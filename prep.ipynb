# %%
import pandas as pd

# %%
data=pd.read_csv('/content/data.csv',na_values = ['#NAME?'])
data
# Out:
#        age         workclass    fnlwgt     education  education_num  \
# 0     39.0         State-gov   77516.0     Bachelors           13.0
# 1     50.0  Self-emp-not-inc   83311.0     Bachelors           13.0
# 2     38.0           Private  215646.0       HS-grad            9.0
# 3     53.0           Private  234721.0          11th            7.0
# 4     28.0           Private  338409.0     Bachelors           13.0
# ...    ...               ...       ...           ...            ...
# 4995  43.0           Private  222971.0       5th-6th            3.0
# 4996  31.0           Private  259425.0       HS-grad            9.0
# 4997  47.0      Self-emp-inc  212120.0       HS-grad            9.0
# 4998   NaN           Private  245880.0       HS-grad            9.0
# 4999  58.0         Local-gov   54947.0  Some-college           10.0
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data.nunique()
# Out:
# age                 69
# workclass            8
# fnlwgt            4507
# education           17
# education_num       17
# marital_status       7
# occupation          15
# relationship         6
# race                 6
# sex                  3
# capital_gain        83
# capital_loss        55
# hours_per_week      74
# native_country      40
# income               2
# dtype: int64

# %%
data['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
data['income']=[0 if x=='<=50K' else 1 for x in data['income']]

# %%
data['income'].unique()
# Out:
# array([0, 1])

# %%
x=data.drop(columns=['income'])
#or data.drop('income', axis ='columns')
# ordata.drop('income', axis = 1)
x
# Out:
#        age         workclass    fnlwgt     education  education_num  \
# 0     39.0         State-gov   77516.0     Bachelors           13.0
# 1     50.0  Self-emp-not-inc   83311.0     Bachelors           13.0
# 2     38.0           Private  215646.0       HS-grad            9.0
# 3     53.0           Private  234721.0          11th            7.0
# 4     28.0           Private  338409.0     Bachelors           13.0
# ...    ...               ...       ...           ...            ...
# 4995  43.0           Private  222971.0       5th-6th            3.0
# 4996  31.0           Private  259425.0       HS-grad            9.0
# 4997  47.0      Self-emp-inc  212120.0       HS-grad            9.0
# 4998   NaN           Private  245880.0       HS-grad            9.0
# 4999  58.0         Local-gov   54947.0  Some-college           10.0
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
y=data['income']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4995    0
# 4996    1
# 4997    1
# 4998    0
# 4999    0
# Name: income, Length: 5000, dtype: int64

# %%
x.isnull().sum()
# Out:
# age                48
# workclass           0
# fnlwgt            107
# education           0
# education_num      57
# marital_status      0
# occupation          0
# relationship        0
# race              264
# sex                47
# capital_gain        0
# capital_loss        0
# hours_per_week      0
# native_country      0
# dtype: int64

# %%
len(x['education'].unique())
# Out:
# 17

# %%
pd.get_dummies(x['education'])
# Out:
#        10th   11th   12th  1st-4th  5th-6th  7th-8th    9th      ?  \
# 0     False  False  False    False    False    False  False  False
# 1     False  False  False    False    False    False  False  False
# 2     False  False  False    False    False    False  False  False
# 3     False   True  False    False    False    False  False  False
# 4     False  False  False    False    False    False  False  False
# ...     ...    ...    ...      ...      ...      ...    ...    ...
# 4995  False  False  False    False     True    False  False  False
# 4996  False  False  False    False    False    False  False  False
# 4997  False  False  False    False    False    False  False  False
# 4998  False  False  False    False    False    False  False  False
# 4999  False  False  False    False    False    False  False  False
#
#       Assoc-acdm  Assoc-voc  Bachelors  Doctorate  HS-grad  Masters  \
# 0          False      False       True      False    False    False
# ...

# %%
for col in x.columns:
  if x[col].dtypes == 'object':
    uniq = len(x[col].unique())
    print(f'Feature : {col} has {uniq} categories')
# Out:
# Feature : workclass has 8 categories
# Feature : education has 17 categories
# Feature : marital_status has 7 categories
# Feature : occupation has 15 categories
# Feature : relationship has 6 categories
# Feature : race has 6 categories
# Feature : sex has 3 categories
# Feature : native_country has 40 categories

# %%
x['native_country'].value_counts().sort_values(ascending=True)
# Out:
# native_country
# Hong                             1
# Scotland                         1
# Thailand                         2
# Yugoslavia                       2
# Laos                             2
# Honduras                         3
# Outlying-US(Guam-USVI-etc)       3
# Peru                             3
# France                           3
# Trinadad&Tobago                  4
# Ireland                          4
# Cambodia                         4
# Ecuador                          4
# Nicaragua                        5
# Columbia                         5
# Haiti                            6
# Greece                           6
# Portugal                         7
# Japan                            9
# South                            9
# Poland                           9
# Taiwan                          10
# Vietnam                         10
# Guatemala                       10
# Iran                            11
# India                           12
# ...

# %%
x['native_country']=['United-States' if x=='United-States' else 'Others' for x in x['native_country']]

# %%
x
# Out:
#        age         workclass    fnlwgt     education  education_num  \
# 0     39.0         State-gov   77516.0     Bachelors           13.0
# 1     50.0  Self-emp-not-inc   83311.0     Bachelors           13.0
# 2     38.0           Private  215646.0       HS-grad            9.0
# 3     53.0           Private  234721.0          11th            7.0
# 4     28.0           Private  338409.0     Bachelors           13.0
# ...    ...               ...       ...           ...            ...
# 4995  43.0           Private  222971.0       5th-6th            3.0
# 4996  31.0           Private  259425.0       HS-grad            9.0
# 4997  47.0      Self-emp-inc  212120.0       HS-grad            9.0
# 4998   NaN           Private  245880.0       HS-grad            9.0
# 4999  58.0         Local-gov   54947.0  Some-college           10.0
#
#           marital_status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...
